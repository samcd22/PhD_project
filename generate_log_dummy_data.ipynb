# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from inference_toolbox.domain import Domain

I_y = 0.1
I_z = 0.1
Q = 3e13

H=10

sigma = 0

domain = Domain('cone_from_source_z_limited', resolution = 20)
domain.add_domain_param('r', 100)
domain.add_domain_param('theta', np.pi/8)
domain.add_domain_param('source', [0,0,10])

points = domain.create_domain()

def C_func(x, y, z, I_y, I_z, Q, H, sigma):
    # mu =  np.log(Q/(np.pi*I_y*I_z*x**2)) + -y**2/(2*I_y**2*x**2) + np.log(np.exp(-(z-H)**2/(2*I_z**2*x**2))+np.exp(-(z+H)**2/(2*I_z**2*x**2)))

    mu =  np.log10(Q/(np.pi*I_y*I_z*x**2)*np.exp(-y**2/(2*I_y**2*x**2))*(np.exp(-(z-H)**2/(2*I_z**2*x**2))+np.exp(-(z+H)**2/(2*I_z**2*x**2))))
    print(mu)
    C = []
    for i in range(len(mu)):
        C.append(mu[i] + sigma*np.random.normal())
    C = np.array(C)
    return C

C = C_func(points[:,0], points[:,1], points[:,2], I_y, I_z, Q, H, sigma)

X = points[:,0]
Y = points[:,1]
Z = points[:,2]

data = pd.DataFrame({'x': X, 'y': Y, 'z': Z, 'Concentration': C})


print(data[data['Concentration']<0])

data.to_csv('./data/log_dummy_data.csv')
data
# Out:
# [11.32308304 11.32308304  9.73682623  9.73682623  9.73682623  9.73682623
#   9.20767078  9.20767078  9.20767078  9.20767078  8.88121608  8.88121608
#  12.16919943 12.16919943  8.88121608  8.88121608  8.64449405  8.64449405
#  11.45906692 11.45906692  8.64449405  8.64449405  8.45866401  8.45866401
#  10.88830016 11.98373395 11.98373395 10.88830016  8.45866401  8.45866401
#   8.30566929  8.30566929 10.43362303 10.43362303 11.59365265 11.59365265
#  10.43362303 10.43362303  8.30566929  8.30566929  8.17563028  8.17563028
#  10.06485168 10.06485168 11.21801072 11.76540227 11.76540227 11.21801072
#  10.06485168 10.06485168  8.17563028  8.17563028  8.06254966  8.06254966
#   9.75949809  9.75949809 10.87712621 11.51299123 11.51299123 10.87712621
#   9.75949809  9.75949809  8.06254966  8.06254966  7.96252337  7.96252337
#   9.50185369  9.50185369 10.5730324  11.25055186 11.57889842 11.57889842
#  11.25055186 10.5730324   9.50185369  9.50185369  7.96252337  7.96252337
#   7.87291491  7.87291491  9.28097003  9.28097003 10.30268407 10.99603115
#  11.39822349 11.39822349 10.99603115 10.30268407  9.28097003  9.28097003
#   7.87291491  7.87291491  7.79195252  7.79195252  9.08916311  9.08916311
#  10.06203226 10.75646777 11.20352868 11.4224558  11.4224558  11.20352868
#  10.75646777 10.06203226  9.08916311  9.08916311  7.79195252  7.79195252
#   7.71848047  7.71848047  8.92098223  8.92098223  9.84726674  9.84726674
#  10.53425497 11.00795649 11.28562397 11.28562397 11.00795649 10.53425497
