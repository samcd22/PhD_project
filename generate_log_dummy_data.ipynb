# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from inference_toolbox.domain import Domain

I_y = 0.1
I_z = 0.1
Q = 3e13

H=10

sigma = 0

domain = Domain('cone_from_source_z_limited', resolution = 20)
domain.add_domain_param('r', 1000)
domain.add_domain_param('theta', np.pi/8)
domain.add_domain_param('source', [0,0,10])

points = domain.create_domain()

def C_func(x, y, z, I_y, I_z, Q, H, sigma):
    # mu =  np.log(Q/(np.pi*I_y*I_z*x**2)) + -y**2/(2*I_y**2*x**2) + np.log(np.exp(-(z-H)**2/(2*I_z**2*x**2))+np.exp(-(z+H)**2/(2*I_z**2*x**2)))

    mu =  np.log10(Q/(np.pi*I_y*I_z*x**2)*np.exp(-y**2/(2*I_y**2*x**2))*(np.exp(-(z-H)**2/(2*I_z**2*x**2))+np.exp(-(z+H)**2/(2*I_z**2*x**2))))
    print(mu)
    C = []
    for i in range(len(mu)):
        C.append(mu[i] + sigma*np.random.normal())
    C = np.array(C)
    return C

C = C_func(points[:,0], points[:,1], points[:,2], I_y, I_z, Q, H, sigma)

X = points[:,0]
Y = points[:,1]
Z = points[:,2]

data = pd.DataFrame({'x': X, 'y': Y, 'z': Z, 'Concentration': C})


print(data[data['Concentration']<0])

data.to_csv('./data/log_dummy_data.csv')
data
# Out:
# [17.32308304 17.32308304  7.88066671  7.88066671  7.88066671  7.88066671
#   7.32800261  7.32800261  7.32800261  7.32800261  7.0695721   7.0695721
#  10.37333531 10.37333531  7.0695721   7.0695721   6.8776973   6.8776973
#   9.7020441   9.7020441   6.8776973   6.8776973   6.7163917   6.7163917
#   9.15203279 10.25021552 10.25021552  9.15203279  6.7163917   6.7163917
#   6.57728419  6.57728419  8.70909647  8.70909647  9.87125046  9.87125046
#   8.70909647  8.70909647  6.57728419  6.57728419  6.45555292  6.45555292
#   8.34737344  8.34737344  9.50212986 10.05028262 10.05028262  9.50212986
#   8.34737344  8.34737344  6.45555292  6.45555292  6.34768683  6.34768683
#   8.04645825  8.04645825  9.16529205  9.80184458  9.80184458  9.16529205
#   8.04645825  8.04645825  6.34768683  6.34768683  6.25104957  6.25104957
#   7.79169202  7.79169202  8.86378068  9.54187283  9.87049577  9.87049577
#   9.54187283  8.86378068  7.79169202  7.79169202  6.25104957  6.25104957
#   6.16363984  6.16363984  7.57262336  7.57262336  8.59499044  9.28876639
#   9.69120073  9.69120073  9.28876639  8.59499044  7.57262336  7.57262336
#   6.16363984  6.16363984  6.08391938  6.08391938  7.38170113  7.38170113
#   8.35494814  9.04961848  9.49681186  9.71579779  9.71579779  9.49681186
#   9.04961848  8.35494814  7.38170113  7.38170113  6.08391938  6.08391938
#   6.01068902  6.01068902  7.2133672   7.2133672   8.13969854  8.13969854
#   8.82665929  9.30030561  9.57792537  9.57792537  9.30030561  8.82665929
